# %% [markdown]
# # **Import Library**

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # **Read Dataset**

# %%
# Mengambil data dari URL
dataset = 'https://raw.githubusercontent.com/arifadli/DatasetRepository/main/EarthquakePrediction/query.csv'
df = pd.read_csv(dataset)

df.head(5)
# Out:
#                        time  latitude  longitude   depth  mag magType  nst  \
# 0  2020-03-30T15:42:33.456Z   36.6765    71.0957  214.05  4.9     mww  NaN
# 1  2020-03-29T18:17:45.513Z   32.9731    76.4202   10.00  4.3      mb  NaN
# 2  2020-03-28T07:38:53.482Z   36.7514    71.3490  176.53  4.4      mb  NaN
# 3  2020-03-28T01:36:51.585Z   37.5638    72.4376  196.81  4.3      mb  NaN
# 4  2020-03-27T11:46:58.989Z   32.6970    76.1440   10.00  4.5      mb  NaN
#
#      gap   dmin   rms  ...                   updated  \
# 0   43.0  2.087  0.75  ...  2020-06-07T13:21:08.040Z
# 1  153.0  2.724  0.65  ...  2020-04-20T14:21:30.718Z
# 2   69.0  2.176  0.64  ...  2020-04-16T06:58:48.040Z
# 3   64.0  1.979  0.97  ...  2020-04-23T23:18:34.040Z
# 4  114.0  2.592  0.75  ...  2020-04-27T12:28:34.040Z
#
#                                 place        type horizontalError depthError  \
# 0        31km SE of Jarm, Afghanistan  earthquake             6.9        6.4
# 1           52km NNE of Chamba, India  earthquake             9.7        1.9
# 2  18km WNW of Ashkasham, Afghanistan  earthquake             7.6        8.4
# 3  63km ENE of Roshtqal'a, Tajikistan  earthquake             6.7        6.5
# 4             14km N of Chamba, India  earthquake             3.7        1.9
#
#    magError  magNst    status  locationSource magSource
# 0     0.098    10.0  reviewed              us        us
# 1     0.133    16.0  reviewed              us        us
# 2     0.096    31.0  reviewed              us        us
# 3     0.092    33.0  reviewed              us        us
# 4     0.083    42.0  reviewed              us        us
#
# [5 rows x 22 columns]
